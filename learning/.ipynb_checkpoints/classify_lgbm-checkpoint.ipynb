# %%
# 選手情報・過去レース情報から3連単舟券120種をクラス分類する
# LGBMでやってみる。
# todo:bayseの方と、インプットの与え方をあわせる。今はOne-Hotが一致していない。
# 的中予想確率10%以上のうち、オッズで見合うものだけ買った場合のシミュレーションをする。

# 汎用ライブラリのimport
import sys
import os
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import statsmodels.api as sm
import math
import tensorflow as tf
import collections

import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import csv

# %%
# 自作ライブラリのimport
if os.environ['BR_HOME']+"/boatrace" not in sys.path:
    sys.path.append(os.environ['BR_HOME']+"/boatrace")
#print(sys.path)

from setup.myUtil import dbHandler

# %%
# 舟券の配列を取得
funakenList=[]
with open(os.environ['BR_HOME']+'/boatrace/config/3t_list.dat') as f:
    reader=csv.reader(f)
    for row in reader:
        funakenList.append(row)
funakenID = [i for i in range(120)]
funakenDict=dict(zip(funakenList[0],funakenID))
print(funakenDict)
# Out:
# {'1-2-3': 0, '1-2-4': 1, '1-2-5': 2, '1-2-6': 3, '1-3-2': 4, '1-3-4': 5, '1-3-5': 6, '1-3-6': 7, '1-4-2': 8, '1-4-3': 9, '1-4-5': 10, '1-4-6': 11, '1-5-2': 12, '1-5-3': 13, '1-5-4': 14, '1-5-6': 15, '1-6-2': 16, '1-6-3': 17, '1-6-4': 18, '1-6-5': 19, '2-1-3': 20, '2-1-4': 21, '2-1-5': 22, '2-1-6': 23, '2-3-1': 24, '2-3-4': 25, '2-3-5': 26, '2-3-6': 27, '2-4-1': 28, '2-4-3': 29, '2-4-5': 30, '2-4-6': 31, '2-5-1': 32, '2-5-3': 33, '2-5-4': 34, '2-5-6': 35, '2-6-1': 36, '2-6-3': 37, '2-6-4': 38, '2-6-5': 39, '3-1-2': 40, '3-1-4': 41, '3-1-5': 42, '3-1-6': 43, '3-2-1': 44, '3-2-4': 45, '3-2-5': 46, '3-2-6': 47, '3-4-1': 48, '3-4-2': 49, '3-4-5': 50, '3-4-6': 51, '3-5-1': 52, '3-5-2': 53, '3-5-4': 54, '3-5-6': 55, '3-6-1': 56, '3-6-2': 57, '3-6-4': 58, '3-6-5': 59, '4-1-2': 60, '4-1-3': 61, '4-1-5': 62, '4-1-6': 63, '4-2-1': 64, '4-2-3': 65, '4-2-5': 66, '4-2-6': 67, '4-3-1': 68, '4-3-2': 69, '4-3-5': 70, '4-3-6': 71, '4-5-1': 72, '4-5-2': 73, '4-5-3': 74, '4-5-6': 75, '4-6-1': 76, '4-6-2': 77, '4-6-3': 78, '4-6-5': 79, '5-1-2': 80, '5-1-3': 81, '5-1-4': 82, '5-1-6': 83, '5-2-1': 84, '5-2-3': 85, '5-2-4': 86, '5-2-6': 87, '5-3-1': 88, '5-3-2': 89, '5-3-4': 90, '5-3-6': 91, '5-4-1': 92, '5-4-2': 93, '5-4-3': 94, '5-4-6': 95, '5-6-1': 96, '5-6-2': 97, '5-6-3': 98, '5-6-4': 99, '6-1-2': 100, '6-1-3': 101, '6-1-4': 102, '6-1-5': 103, '6-2-1': 104, '6-2-3': 105, '6-2-4': 106, '6-2-5': 107, '6-3-1': 108, '6-3-2': 109, '6-3-4': 110, '6-3-5': 111, '6-4-1': 112, '6-4-2': 113, '6-4-3': 114, '6-4-5': 115, '6-5-1': 116, '6-5-2': 117, '6-5-3': 118, '6-5-4': 119}

# %%
# 分析期間の指定は一旦ここでまとめてみる。
trainStartDate="20180101"
trainEndDate="20180731"
# test はtrainからsplitする

# %%
dbh=dbHandler.getDBHandle()
#dbHandler.closeDBHandle(dbh)

# %%
# trainの元データを取得
with dbh.cursor() as cursor:
    sel_sql = "select * from raceabst_forml_v \
               where raceDate between '%s' and '%s' \
               order by raceId "\
               % (trainStartDate,trainEndDate)
    cursor.execute(sel_sql)
    loadList=cursor.fetchall()
print("traindata:",len(loadList))
# Out:
# traindata: 31824

# %%
df = pd.io.json.json_normalize(loadList)
df.head()
# Out:
#   funaken  l1Fcnt  l1boat2r  l1boat3r  l1motor2r  l1motor3r l1rank    l1score  \
# 0   2-1-3       1    0.3636    0.5152     0.3558     0.5092     A1  13.871549
# 1   2-1-6       0    0.2462    0.4462     0.3466     0.4830     B1   3.409304
# 2   3-5-4       0    0.3692    0.5231     0.3135     0.4108     B2   2.836839
# 3   1-5-2       0    0.4308    0.6308     0.3676     0.5514     A2   7.488113
# 4   4-1-3       0    0.3636    0.5152     0.4469     0.5754     B1   6.454111
#
#    l2Fcnt  l2boat2r  ...  l6boat3r  l6motor2r  l6motor3r l6rank   l6score  \
# 0       0    0.4746  ...    0.4545     0.5421     0.6789     B2  0.851669
# 1       0    0.3636  ...    0.4925     0.3392     0.5088     B1  0.886552
# 2       0    0.2714  ...    0.4091     0.3472     0.4870     B1  0.580764
# 3       0    0.3636  ...    0.3939     0.3176     0.4706     B1  0.583266
# 4       0    0.3231  ...    0.4925     0.3916     0.5663     B2  0.470489
#
#    odds    raceDate          raceId  raceWaveHeight  raceWindSpeed
# 0  30.9  2018-01-01  20180101-06-01               3            5.0
# 1  26.2  2018-01-01  20180101-06-02               3            5.0
# 2  99.2  2018-01-01  20180101-06-03               3            5.0
# 3  16.8  2018-01-01  20180101-06-04               3            5.0
# 4  51.5  2018-01-01  20180101-06-05               3            5.0
#
# [5 rows x 48 columns]

# %%
# 入力のデータ整形
#xdf=df.drop(['funaken','odds','raceId','raceDate'],axis=1)
#xdf=pd.get_dummies(xdf,columns=['l1rank','l2rank','l3rank','l4rank','l5rank','l6rank'])
#xdf.head()

# 入力のデータ整形
xdf=df.drop(['funaken','odds','raceId','raceDate'],axis=1)
#xdf=pd.get_dummies(xdf,columns=['l1rank','l2rank','l3rank','l4rank','l5rank','l6rank'])
rankLabel=LabelEncoder()
rankLabel=rankLabel.fit(xdf['l1rank'])
xdf['l1rank']=rankLabel.transform(xdf['l1rank'])
xdf['l2rank']=rankLabel.transform(xdf['l2rank'])
xdf['l3rank']=rankLabel.transform(xdf['l3rank'])
xdf['l4rank']=rankLabel.transform(xdf['l4rank'])
xdf['l5rank']=rankLabel.transform(xdf['l5rank'])
xdf['l6rank']=rankLabel.transform(xdf['l6rank'])
xdf.head()
# Out:
#    l1Fcnt  l1boat2r  l1boat3r  l1motor2r  l1motor3r  l1rank    l1score  \
# 0       1    0.3636    0.5152     0.3558     0.5092       0  13.871549
# 1       0    0.2462    0.4462     0.3466     0.4830       2   3.409304
# 2       0    0.3692    0.5231     0.3135     0.4108       3   2.836839
# 3       0    0.4308    0.6308     0.3676     0.5514       1   7.488113
# 4       0    0.3636    0.5152     0.4469     0.5754       2   6.454111
#
#    l2Fcnt  l2boat2r  l2boat3r  ...   l5score  l6Fcnt  l6boat2r  l6boat3r  \
# 0       0    0.4746    0.6610  ...  0.827756       0    0.3182    0.4545
# 1       0    0.3636    0.5758  ...  0.671987       0    0.3284    0.4925
# 2       0    0.2714    0.5000  ...  4.669515       0    0.3030    0.4091
# 3       0    0.3636    0.5303  ...  1.435647       0    0.2121    0.3939
# 4       0    0.3231    0.6154  ...  1.682992       0    0.3582    0.4925
#
#    l6motor2r  l6motor3r  l6rank   l6score  raceWaveHeight  raceWindSpeed
# 0     0.5421     0.6789       3  0.851669               3            5.0
# 1     0.3392     0.5088       2  0.886552               3            5.0
# 2     0.3472     0.4870       2  0.580764               3            5.0
# 3     0.3176     0.4706       2  0.583266               3            5.0
# 4     0.3916     0.5663       3  0.470489               3            5.0
#
# [5 rows x 44 columns]

# %%
# ファイルから作った辞書で変換する
ydf=df['funaken']
ydf=pd.DataFrame(ydf.replace(funakenDict))
print(ydf.head())
# Out:
#    funaken
# 0       20
# 1       23
# 2       54
# 3       12
# 4       61

# %%
# 重み付けのため、オッズのリストを作る
odf=df['odds'].values
#odf=pd.DataFrame(df['odds'])
#odf.describe()
print(odf)
# Out:
# [30.9 26.2 99.2 ...  5.1  7.9  5.7]

# %%
X_train, X_test, y_train, y_test,o_train,o_test = train_test_split(xdf, ydf,odf)

# %%
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# %%
lgbm_params = {
    # 多値分類問題
    'objective': 'multiclass',
    # クラス数は 120
    'num_class': 120,
    #'class_weight':'balanced',
    'random_state':999,
    # 以下、ハイパーパラメタ
    'max_depth':3,
    'num_leaves':19,
    'min_data_in_leaf':300,
    # 正則化
    'reg_alpha':9.591,
    'reg_lambda':9.928 ,
}

# %%
lgb.LGBMClassifier()
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
model = lgb.train(lgbm_params, lgb_train, valid_sets=lgb_eval)
# Out:
# [1]	valid_0's multi_logloss: 4.66987
# [2]	valid_0's multi_logloss: 4.5842
# [3]	valid_0's multi_logloss: 4.51629
# [4]	valid_0's multi_logloss: 4.45924
# [5]	valid_0's multi_logloss: 4.4101
# [6]	valid_0's multi_logloss: 4.36803
# [7]	valid_0's multi_logloss: 4.33074
# [8]	valid_0's multi_logloss: 4.29818
# [9]	valid_0's multi_logloss: 4.26811
# [10]	valid_0's multi_logloss: 4.24163
# [11]	valid_0's multi_logloss: 4.2176
# [12]	valid_0's multi_logloss: 4.19654
# [13]	valid_0's multi_logloss: 4.17694
# [14]	valid_0's multi_logloss: 4.15902
# [15]	valid_0's multi_logloss: 4.14221
# [16]	valid_0's multi_logloss: 4.12692
# [17]	valid_0's multi_logloss: 4.11272
# [18]	valid_0's multi_logloss: 4.0997
# [19]	valid_0's multi_logloss: 4.08734
# [20]	valid_0's multi_logloss: 4.07629
# [21]	valid_0's multi_logloss: 4.06605
# [22]	valid_0's multi_logloss: 4.05657
# [23]	valid_0's multi_logloss: 4.0475
# [24]	valid_0's multi_logloss: 4.03899
# [25]	valid_0's multi_logloss: 4.03117
# [26]	valid_0's multi_logloss: 4.0239
# [27]	valid_0's multi_logloss: 4.01685
# [28]	valid_0's multi_logloss: 4.01029
# [29]	valid_0's multi_logloss: 4.00399
# [30]	valid_0's multi_logloss: 3.99815
# [31]	valid_0's multi_logloss: 3.9929
# [32]	valid_0's multi_logloss: 3.98794
# [33]	valid_0's multi_logloss: 3.98313
# [34]	valid_0's multi_logloss: 3.97844
# [35]	valid_0's multi_logloss: 3.97421
# [36]	valid_0's multi_logloss: 3.97025
# [37]	valid_0's multi_logloss: 3.9664
# [38]	valid_0's multi_logloss: 3.96289
# [39]	valid_0's multi_logloss: 3.95937
# [40]	valid_0's multi_logloss: 3.95607
# [41]	valid_0's multi_logloss: 3.95306
# [42]	valid_0's multi_logloss: 3.95008
# [43]	valid_0's multi_logloss: 3.94731
# [44]	valid_0's multi_logloss: 3.94448
# [45]	valid_0's multi_logloss: 3.94216
# [46]	valid_0's multi_logloss: 3.94001
# [47]	valid_0's multi_logloss: 3.93774
# [48]	valid_0's multi_logloss: 3.93568
# [49]	valid_0's multi_logloss: 3.93375
# [50]	valid_0's multi_logloss: 3.93183
# [51]	valid_0's multi_logloss: 3.93001
# [52]	valid_0's multi_logloss: 3.92851
# [53]	valid_0's multi_logloss: 3.92695
# [54]	valid_0's multi_logloss: 3.92556
# [55]	valid_0's multi_logloss: 3.92399
# [56]	valid_0's multi_logloss: 3.92262
# [57]	valid_0's multi_logloss: 3.92118
# [58]	valid_0's multi_logloss: 3.91987
# [59]	valid_0's multi_logloss: 3.9186
# [60]	valid_0's multi_logloss: 3.91731
# [61]	valid_0's multi_logloss: 3.9162
# [62]	valid_0's multi_logloss: 3.91523
# [63]	valid_0's multi_logloss: 3.91423
# [64]	valid_0's multi_logloss: 3.91321
# [65]	valid_0's multi_logloss: 3.91241
# [66]	valid_0's multi_logloss: 3.91149
# [67]	valid_0's multi_logloss: 3.91065
# [68]	valid_0's multi_logloss: 3.90998
# [69]	valid_0's multi_logloss: 3.90913
# [70]	valid_0's multi_logloss: 3.90839
# [71]	valid_0's multi_logloss: 3.90774
# [72]	valid_0's multi_logloss: 3.90703
# [73]	valid_0's multi_logloss: 3.90641
# [74]	valid_0's multi_logloss: 3.90578
# [75]	valid_0's multi_logloss: 3.90511
# [76]	valid_0's multi_logloss: 3.90463
# [77]	valid_0's multi_logloss: 3.9041
# [78]	valid_0's multi_logloss: 3.90368
# [79]	valid_0's multi_logloss: 3.90297
# [80]	valid_0's multi_logloss: 3.90255
# [81]	valid_0's multi_logloss: 3.90205
# [82]	valid_0's multi_logloss: 3.9016
# [83]	valid_0's multi_logloss: 3.90112
# [84]	valid_0's multi_logloss: 3.90068
# [85]	valid_0's multi_logloss: 3.90019
# [86]	valid_0's multi_logloss: 3.89996
# [87]	valid_0's multi_logloss: 3.89971
# [88]	valid_0's multi_logloss: 3.89932
# [89]	valid_0's multi_logloss: 3.89895
# [90]	valid_0's multi_logloss: 3.89866
# [91]	valid_0's multi_logloss: 3.89835
# [92]	valid_0's multi_logloss: 3.8979
# [93]	valid_0's multi_logloss: 3.89768
# [94]	valid_0's multi_logloss: 3.89736
# [95]	valid_0's multi_logloss: 3.89707
# [96]	valid_0's multi_logloss: 3.89685
# [97]	valid_0's multi_logloss: 3.89662
# [98]	valid_0's multi_logloss: 3.89656
# [99]	valid_0's multi_logloss: 3.89634
# [100]	valid_0's multi_logloss: 3.89596

# %%
y_pred = model.predict(X_test, num_iteration=model.best_iteration)
y_pred_max = np.argmax(y_pred, axis=1)  # 最尤と判断したクラスの値にする

# 精度 (Accuracy) を計算する
accuracy = sum(y_test['funaken'] == y_pred_max) / len(y_test)
print("accuracy:",accuracy)

# 回収率を計算
res=0
for i in range(len(y_test)):
    if (y_test.iloc[i])['funaken']==y_pred_max[i]:
        #print("i:",i,"result:",y_test[i],"forecast:",y_pred_max[i],"forecastProb:",y_pred[i][y_pred_max[i]],"return:",o_test[i],"expect:",y_pred[i][y_pred_max[i]]*o_test[i])
        res += o_test[i] -1
    else:
        #print("i:",i,"result:",y_test[i],"forecast:",y_pred_max[i],"forecastProb:",y_pred[i][y_pred_max[i]],"return:",o_test[i],"expect:",y_pred[i][y_pred_max[i]]*o_test[i])
        pass
print("resultReturn:",res/len(y_test))
# Out:
# accuracy: 0.08660130718954248
# resultReturn: 0.7279160382101564

# %%
print(len(y_pred))
# オッズを見て判断する場合
resAmount=0
buyAmount=0

dfIndexList=y_test['funaken'].index
for i in range(len(y_test)):
    raceId = df.iloc[dfIndexList[i]]['raceId']
    #print(raceId)
    with dbh.cursor() as cursor:
        sel_sql = "select funaken,odds from raceodds \
                   where oddsType = '3t' \
                   and raceId = '%s' \
                   order by funaken" \
                   % (raceId)
        cursor.execute(sel_sql)
        loadList=pd.DataFrame(cursor.fetchall())
        loadList=pd.DataFrame(loadList.replace(funakenDict))
    #print((loadList[loadList['funaken']==0]['odds'] * y_pred[i][0] ).values[0] )
    #if ( (loadList[loadList['funaken']==0]['odds'] * y_pred[i][0] ).values[0] > 1) :
    #    print("ok")
    #print(y_pred[i][0])
    #print(raceId)
    for j in range(120):
        if y_pred[i][j]> 0.10 and ( (y_pred[i][j] * (loadList[loadList['funaken']==j]['odds'])).values[0] > 1.5) :
            print("buy:",raceId,i,j,loadList[loadList['funaken']==j]['odds'].values[0])
            buyAmount+=1
            if y_test['funaken'].iloc[i]==j:
            #print("i:",i,"result:",y_test[i],"forecast:",y_pred_max[i],"forecastProb:",y_pred[i][y_pred_max[i]],"return:",o_test[i],"expect:",y_pred[i][y_pred_max[i]]*o_test[i])
                print("☆hit!☆:",raceId,j,loadList[loadList['funaken']==j]['odds'].values[0])
                resAmount += o_test[i]
            else:
            #print("i:",i,"result:",y_test[i],"forecast:",y_pred_max[i],"forecastProb:",y_pred[i][y_pred_max[i]],"return:",o_test[i],"expect:",y_pred[i][y_pred_max[i]]*o_test[i])
# buy: 20180104-06-08 7039 12 25.2
# buy: 20180501-13-03 7044 5 12.2
# buy: 20180310-07-12 7047 1 25.3
# buy: 20180313-04-01 7055 1 12.8
# buy: 20180527-04-11 7092 21 14.9
# buy: 20180617-12-05 7162 1 13.0
# buy: 20180727-18-03 7231 1 14.7
# buy: 20180517-22-05 7239 0 18.9
# buy: 20180408-22-08 7262 9 13.5
# buy: 20180430-13-07 7263 3 30.0
# buy: 20180524-17-06 7269 0 14.3
# buy: 20180428-12-03 7351 20 17.6
# buy: 20180513-07-07 7378 0 17.6
# buy: 20180606-20-12 7395 0 15.5
# buy: 20180502-10-02 7423 0 21.3
# buy: 20180305-14-07 7431 1 18.1
# buy: 20180512-18-01 7438 4 12.9
# buy: 20180709-22-03 7482 2 10.3
# buy: 20180207-23-02 7503 1 80.2
# buy: 20180609-21-05 7508 1 9.3
# buy: 20180514-19-08 7510 0 38.6
# buy: 20180602-02-07 7520 0 48.7
# buy: 20180516-09-08 7546 0 12.7
# buy: 20180516-09-08 7546 1 80.9
# buy: 20180707-10-12 7549 0 10.9
# buy: 20180712-09-07 7621 0 21.5
# buy: 20180712-09-07 7621 4 14.5
# buy: 20180313-01-10 7646 0 12.6
# buy: 20180421-08-04 7670 0 11.1
# buy: 20180612-14-05 7689 0 15.4
# buy: 20180117-19-09 7742 0 15.3
# buy: 20180610-24-09 7743 2 15.1
# buy: 20180312-12-12 7776 11 11.9
# ☆hit!☆: 20180312-12-12 11 11.9
# buy: 20180613-10-06 7790 12 34.3
# buy: 20180225-10-01 7845 0 14.8
# buy: 20180427-23-03 7848 0 16.4
# buy: 20180522-08-06 7849 0 14.3
# buy: 20180227-09-05 7878 0 15.5
# buy: 20180609-06-09 7928 0 16.2
# buy: 20180331-18-01 7953 2 17.9
# resultReturn: 0.9603333333333333

# %%
print("totalRace,buy,return",len(y_test),buyAmount,resAmount )
# Out:
# totalRace,buy,return 7956 300 288.09999999999997

# %%
# trainの回収率を計算
y_pred = model.predict(X_train, num_iteration=model.best_iteration)
y_pred_max = np.argmax(y_pred, axis=1)  # 最尤と判断したクラスの値にする

#print(X_train.head())
#print(y_train[0:5])
#print(y_pred_max[0:5])
#c = collections.Counter(y_pred_max)
#print(len(c) )

# 精度 (Accuracy) を計算する
accuracy = sum(y_train == y_pred_max) / len(y_train)
print("accuracy:",accuracy)

# 回収率を計算
res=0
for i in range(len(y_train)):
    if y_train.iloc[i]==y_pred_max[i]:
        res += o_train[i] -1
    else:
        pass
print("return:",res/len(y_train))
# Out:
# accuracy: 0.15254734372381432
# return: 1.6404767890061995

# %%
print(y_pred[0])
# Out:
# [0.16325538 0.08015782 0.09847157 0.0193496  0.07342523 0.0341735
#  0.03888798 0.00830498 0.06171979 0.02266775 0.03685082 0.00557308
#  0.0666263  0.01264112 0.01730488 0.00404506 0.00392837 0.00303416
#  0.00286295 0.00155773 0.04369695 0.00799778 0.02450095 0.0053066
#  0.00567482 0.00178753 0.00303634 0.00185662 0.00379114 0.00213292
#  0.00114678 0.00122078 0.00242561 0.0012388  0.00238295 0.00084877
#  0.00117216 0.00100795 0.00083239 0.0009667  0.00532319 0.00293772
#  0.00350938 0.00257052 0.00253015 0.00215458 0.00163988 0.00114257
#  0.00205868 0.00317003 0.00167596 0.00099296 0.00164794 0.0017303
#  0.00138308 0.00109713 0.00080937 0.00130603 0.00068086 0.00069282
#  0.00423586 0.00258704 0.0052843  0.00177792 0.00290934 0.00134249
#  0.00163997 0.00110285 0.00139556 0.00180939 0.00298379 0.00096123
#  0.00364094 0.00276216 0.00243222 0.00143256 0.0011333  0.0006861
#  0.00107718 0.00126817 0.00682508 0.00364191 0.00467418 0.00111447
#  0.00180396 0.00122093 0.00100456 0.00078043 0.0017301  0.00076718
#  0.00075802 0.00095687 0.00178655 0.00169523 0.00098762 0.00097537
#  0.0018058  0.00071287 0.00068011 0.00078683 0.001277   0.00132368
#  0.00072805 0.00079747 0.00109832 0.00090135 0.00094821 0.00059081
#  0.00070554 0.00062298 0.00058891 0.00072482 0.00082795 0.00071976
#  0.00062065 0.00079111 0.0007507  0.000725   0.0006602  0.00051128]

# %%
print(df.iloc[X_train.index]['raceId'])
# Out:
# 21616    20180524-24-03
# 13722    20180403-07-09
# 12788    20180326-17-09
# 30986    20180725-20-09
# 1638     20180109-14-09
# 30344    20180721-18-01
# 15707    20180417-02-07
# 5794     20180207-04-12
# 124      20180101-20-05
# 15187    20180414-06-01
# 5077     20180202-04-07
# 30248    20180721-02-09
# 4989     20180201-13-01
# 8310     20180225-19-02
# 4125     20180127-02-03
# 29431    20180715-08-03
# 9325     20180304-20-03
# 13178    20180329-13-03
# 8754     20180228-22-06
# 8933     20180302-15-04
# 3413     20180121-10-12
# 31669    20180730-19-02
# 6987     20180217-16-04
# 8662     20180228-02-10
# 7643     20180222-13-06
# 12242    20180322-22-11
# 11671    20180318-21-06
# 16877    20180425-20-05
# 10254    20180310-17-07
# 15584    20180416-11-03
#               ...
# 29031    20180712-17-10
# 26067    20180622-18-11
# 22921    20180602-01-05
# 26435    20180625-08-10
# 25068    20180616-04-01
# 22818    20180601-11-10
# 13138    20180329-02-11
# 16092    20180419-19-10
# 18583    20180504-19-04
# 3146     20180119-08-08
# 23978    20180608-21-01
# 4072     20180126-18-10
# 6937     20180217-06-01
# 4668     20180130-10-02
# 30703    20180723-24-01
# 9999     20180309-03-12
# 1352     20180107-20-10
# 17963    20180501-06-07
# 11475    20180317-21-01
# 5616     20180205-20-11
# 8893     20180302-06-12
# 7339     20180220-13-12
# 10748    20180313-10-09
# 22169    20180528-07-03
# 11867    20180320-06-11
# 23473    20180605-15-06
# 18232    20180502-14-03
# 22395    20180529-16-05
# 19425    20180509-18-06
# 12425    20180324-08-02
# Name: raceId, Length: 23868, dtype: object

# %%
print(model.feature_importance())
# Out:
# [  96 1031 1251  858 1106 5396   83 1181 1115  894 1210 5285   89  784
#  1027 1090 1082 5657   69 1047  909 1158 1011 6521  139 1234 1137 1173
#  1016 7256   94  918 1074  876  966 6603  528  502   43   48  149   55
#   140   73  130   27  164  122  318   60  119   85   96  133   88  104
#   131  245  141   85  108  145]
