# %%
# 選手情報・過去レース情報から3連単舟券120種をクラス分類する
# LGBMでやってみる。
# todo:bayseの方と、インプットの与え方をあわせる。今はOne-Hotが一致していない。
# 的中予想確率10%以上のうち、オッズで見合うものだけ買った場合のシミュレーションをする。

# 汎用ライブラリのimport
import sys
import os
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import statsmodels.api as sm
import math
import tensorflow as tf
import collections

import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import csv

# %%
# 自作ライブラリのimport
if os.environ['BR_HOME']+"/boatrace" not in sys.path:
    sys.path.append(os.environ['BR_HOME']+"/boatrace")
#print(sys.path)

from setup.myUtil import dbHandler

# %%
# 舟券の配列を取得
funakenList=[]
with open(os.environ['BR_HOME']+'/boatrace/config/3t_list.dat') as f:
    reader=csv.reader(f)
    for row in reader:
        funakenList.append(row)
funakenID = [i for i in range(120)]
funakenDict=dict(zip(funakenList[0],funakenID))
print(funakenDict)
# Out:
# {'1-2-3': 0, '1-2-4': 1, '1-2-5': 2, '1-2-6': 3, '1-3-2': 4, '1-3-4': 5, '1-3-5': 6, '1-3-6': 7, '1-4-2': 8, '1-4-3': 9, '1-4-5': 10, '1-4-6': 11, '1-5-2': 12, '1-5-3': 13, '1-5-4': 14, '1-5-6': 15, '1-6-2': 16, '1-6-3': 17, '1-6-4': 18, '1-6-5': 19, '2-1-3': 20, '2-1-4': 21, '2-1-5': 22, '2-1-6': 23, '2-3-1': 24, '2-3-4': 25, '2-3-5': 26, '2-3-6': 27, '2-4-1': 28, '2-4-3': 29, '2-4-5': 30, '2-4-6': 31, '2-5-1': 32, '2-5-3': 33, '2-5-4': 34, '2-5-6': 35, '2-6-1': 36, '2-6-3': 37, '2-6-4': 38, '2-6-5': 39, '3-1-2': 40, '3-1-4': 41, '3-1-5': 42, '3-1-6': 43, '3-2-1': 44, '3-2-4': 45, '3-2-5': 46, '3-2-6': 47, '3-4-1': 48, '3-4-2': 49, '3-4-5': 50, '3-4-6': 51, '3-5-1': 52, '3-5-2': 53, '3-5-4': 54, '3-5-6': 55, '3-6-1': 56, '3-6-2': 57, '3-6-4': 58, '3-6-5': 59, '4-1-2': 60, '4-1-3': 61, '4-1-5': 62, '4-1-6': 63, '4-2-1': 64, '4-2-3': 65, '4-2-5': 66, '4-2-6': 67, '4-3-1': 68, '4-3-2': 69, '4-3-5': 70, '4-3-6': 71, '4-5-1': 72, '4-5-2': 73, '4-5-3': 74, '4-5-6': 75, '4-6-1': 76, '4-6-2': 77, '4-6-3': 78, '4-6-5': 79, '5-1-2': 80, '5-1-3': 81, '5-1-4': 82, '5-1-6': 83, '5-2-1': 84, '5-2-3': 85, '5-2-4': 86, '5-2-6': 87, '5-3-1': 88, '5-3-2': 89, '5-3-4': 90, '5-3-6': 91, '5-4-1': 92, '5-4-2': 93, '5-4-3': 94, '5-4-6': 95, '5-6-1': 96, '5-6-2': 97, '5-6-3': 98, '5-6-4': 99, '6-1-2': 100, '6-1-3': 101, '6-1-4': 102, '6-1-5': 103, '6-2-1': 104, '6-2-3': 105, '6-2-4': 106, '6-2-5': 107, '6-3-1': 108, '6-3-2': 109, '6-3-4': 110, '6-3-5': 111, '6-4-1': 112, '6-4-2': 113, '6-4-3': 114, '6-4-5': 115, '6-5-1': 116, '6-5-2': 117, '6-5-3': 118, '6-5-4': 119}

# %%
# 分析期間の指定は一旦ここでまとめてみる。
trainStartDate="20170401"
trainEndDate="20190331"
# test はtrainからsplitする

# %%
dbh=dbHandler.getDBHandle()
#dbHandler.closeDBHandle(dbh)

# %%
# trainの元データを取得
with dbh.cursor() as cursor:
    sel_sql = "select * from raceabst_forml_v \
               where raceDate between '%s' and '%s' \
               order by raceId "\
               % (trainStartDate,trainEndDate)
    cursor.execute(sel_sql)
    loadList=cursor.fetchall()
print("traindata:",len(loadList))
# Out:
# traindata: 108689

# %%
df = pd.io.json.json_normalize(loadList)
df.head()
# Out:
#   funaken  l1Fcnt  l1boat2r  l1boat3r  l1motor2r  l1motor3r l1rank    l1score  \
# 0   1-5-2       0    0.3333    0.4848     0.3817     0.5645     B1   4.842381
# 1   2-1-3       1    0.2876    0.4248     0.3960     0.6040     B1   7.406036
# 2   2-3-1       1    0.2452    0.4387     0.4610     0.5779     B1   8.340631
# 3   1-4-2       0    0.1959    0.3986     0.6369     0.7738     B1   9.654840
# 4   1-2-4       0    0.3609    0.4852     0.2983     0.4475     A2  15.248551
#
#    l2Fcnt  l2boat2r  ...  l6boat3r  l6motor2r  l6motor3r l6rank   l6score  \
# 0       0    0.3333  ...    0.4452     0.3134     0.4478     B2  0.594831
# 1       0    0.3871  ...    0.4177     0.4500     0.5750     B1  1.504087
# 2       1    0.3807  ...    0.4938     0.3541     0.5502     A2  3.195143
# 3       0    0.3439  ...    0.3846     0.3161     0.4540     B1  0.583962
# 4       0    0.2911  ...    0.5375     0.4296     0.6667     A2  2.543009
#
#    odds    raceDate          raceId  raceWaveHeight  raceWindSpeed
# 0  30.3  2017-04-01  20170401-02-01               1            2.0
# 1  79.0  2017-04-01  20170401-02-02               1            2.0
# 2  28.9  2017-04-01  20170401-02-03               1            3.0
# 3   7.7  2017-04-01  20170401-02-04               1            3.0
# 4  52.7  2017-04-01  20170401-02-05               1            2.0
#
# [5 rows x 48 columns]

# %%
# 入力のデータ整形
#xdf=df.drop(['funaken','odds','raceId','raceDate'],axis=1)
#xdf=pd.get_dummies(xdf,columns=['l1rank','l2rank','l3rank','l4rank','l5rank','l6rank'])
#xdf.head()

# 入力のデータ整形
xdf=df.drop(['funaken','odds','raceId','raceDate'],axis=1)
#xdf=pd.get_dummies(xdf,columns=['l1rank','l2rank','l3rank','l4rank','l5rank','l6rank'])
rankLabel=LabelEncoder()
rankLabel=rankLabel.fit(xdf['l1rank'])
xdf['l1rank']=rankLabel.transform(xdf['l1rank'])
xdf['l2rank']=rankLabel.transform(xdf['l2rank'])
xdf['l3rank']=rankLabel.transform(xdf['l3rank'])
xdf['l4rank']=rankLabel.transform(xdf['l4rank'])
xdf['l5rank']=rankLabel.transform(xdf['l5rank'])
xdf['l6rank']=rankLabel.transform(xdf['l6rank'])
xdf.head()
# Out:
#    l1Fcnt  l1boat2r  l1boat3r  l1motor2r  l1motor3r  l1rank    l1score  \
# 0       0    0.3333    0.4848     0.3817     0.5645       2   4.842381
# 1       1    0.2876    0.4248     0.3960     0.6040       2   7.406036
# 2       1    0.2452    0.4387     0.4610     0.5779       2   8.340631
# 3       0    0.1959    0.3986     0.6369     0.7738       2   9.654840
# 4       0    0.3609    0.4852     0.2983     0.4475       1  15.248551
#
#    l2Fcnt  l2boat2r  l2boat3r  ...    l5score  l6Fcnt  l6boat2r  l6boat3r  \
# 0       0    0.3333    0.5094  ...   2.860248       0    0.2740    0.4452
# 1       0    0.3871    0.5935  ...   2.015905       1    0.2532    0.4177
# 2       1    0.3807    0.5739  ...   1.279918       0    0.3125    0.4938
# 3       0    0.3439    0.5350  ...   1.545834       0    0.2231    0.3846
# 4       0    0.2911    0.4557  ...  11.021105       1    0.3500    0.5375
#
#    l6motor2r  l6motor3r  l6rank   l6score  raceWaveHeight  raceWindSpeed
# 0     0.3134     0.4478       3  0.594831               1            2.0
# 1     0.4500     0.5750       2  1.504087               1            2.0
# 2     0.3541     0.5502       1  3.195143               1            3.0
# 3     0.3161     0.4540       2  0.583962               1            3.0
# 4     0.4296     0.6667       1  2.543009               1            2.0
#
# [5 rows x 44 columns]

# %%
# ファイルから作った辞書で変換する
ydf=df['funaken']
ydf=pd.DataFrame(ydf.replace(funakenDict))
print(ydf.head())
# Out:
#    funaken
# 0       12
# 1       20
# 2       24
# 3        8
# 4        1

# %%
# 重み付けのため、オッズのリストを作る
odf=df['odds'].values
#odf=pd.DataFrame(df['odds'])
#odf.describe()
print(odf)
# Out:
# [  30.3   79.    28.9 ...   13.6 1094.    29.2]

# %%
X_train, X_test, y_train, y_test,o_train,o_test = train_test_split(xdf, ydf,odf)

# %%
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# %%
lgbm_params = {
    # 多値分類問題
    'objective': 'multiclass',
    # クラス数は 120
    'num_class': 120,
    #'class_weight':'balanced',
    'random_state':999,
    # 以下、ハイパーパラメタ
    'max_depth':3,
    'num_leaves':6,
    'min_data_in_leaf':300,
    # 正則化
    'reg_alpha':2.425,
    'reg_lambda':9.473 ,
}

# %%
lgb.LGBMClassifier()
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
model = lgb.train(lgbm_params, lgb_train, valid_sets=lgb_eval)
# Out:
# [1]	valid_0's multi_logloss: 4.66058
# [2]	valid_0's multi_logloss: 4.57111
# [3]	valid_0's multi_logloss: 4.49936
# [4]	valid_0's multi_logloss: 4.44017
# [5]	valid_0's multi_logloss: 4.38987
# [6]	valid_0's multi_logloss: 4.34574
# [7]	valid_0's multi_logloss: 4.30728
# [8]	valid_0's multi_logloss: 4.273
# [9]	valid_0's multi_logloss: 4.24248
# [10]	valid_0's multi_logloss: 4.21476
# [11]	valid_0's multi_logloss: 4.18977
# [12]	valid_0's multi_logloss: 4.16722
# [13]	valid_0's multi_logloss: 4.14635
# [14]	valid_0's multi_logloss: 4.12748
# [15]	valid_0's multi_logloss: 4.11002
# [16]	valid_0's multi_logloss: 4.09401
# [17]	valid_0's multi_logloss: 4.07937
# [18]	valid_0's multi_logloss: 4.06576
# [19]	valid_0's multi_logloss: 4.05321
# [20]	valid_0's multi_logloss: 4.04133
# [21]	valid_0's multi_logloss: 4.03036
# [22]	valid_0's multi_logloss: 4.02048
# [23]	valid_0's multi_logloss: 4.01101
# [24]	valid_0's multi_logloss: 4.00217
# [25]	valid_0's multi_logloss: 3.9938
# [26]	valid_0's multi_logloss: 3.9862
# [27]	valid_0's multi_logloss: 3.97885
# [28]	valid_0's multi_logloss: 3.97209
# [29]	valid_0's multi_logloss: 3.96577
# [30]	valid_0's multi_logloss: 3.95986
# [31]	valid_0's multi_logloss: 3.95427
# [32]	valid_0's multi_logloss: 3.94901
# [33]	valid_0's multi_logloss: 3.94403
# [34]	valid_0's multi_logloss: 3.9393
# [35]	valid_0's multi_logloss: 3.9349
# [36]	valid_0's multi_logloss: 3.93075
# [37]	valid_0's multi_logloss: 3.92689
# [38]	valid_0's multi_logloss: 3.92307
# [39]	valid_0's multi_logloss: 3.91953
# [40]	valid_0's multi_logloss: 3.91614
# [41]	valid_0's multi_logloss: 3.91298
# [42]	valid_0's multi_logloss: 3.91013
# [43]	valid_0's multi_logloss: 3.90726
# [44]	valid_0's multi_logloss: 3.90436
# [45]	valid_0's multi_logloss: 3.90188
# [46]	valid_0's multi_logloss: 3.8995
# [47]	valid_0's multi_logloss: 3.89723
# [48]	valid_0's multi_logloss: 3.89511
# [49]	valid_0's multi_logloss: 3.89314
# [50]	valid_0's multi_logloss: 3.89108
# [51]	valid_0's multi_logloss: 3.88913
# [52]	valid_0's multi_logloss: 3.88732
# [53]	valid_0's multi_logloss: 3.88576
# [54]	valid_0's multi_logloss: 3.88422
# [55]	valid_0's multi_logloss: 3.8825
# [56]	valid_0's multi_logloss: 3.88109
# [57]	valid_0's multi_logloss: 3.87974
# [58]	valid_0's multi_logloss: 3.87836
# [59]	valid_0's multi_logloss: 3.87716
# [60]	valid_0's multi_logloss: 3.87599
# [61]	valid_0's multi_logloss: 3.87486
# [62]	valid_0's multi_logloss: 3.87373
# [63]	valid_0's multi_logloss: 3.8727
# [64]	valid_0's multi_logloss: 3.87179
# [65]	valid_0's multi_logloss: 3.87078
# [66]	valid_0's multi_logloss: 3.86993
# [67]	valid_0's multi_logloss: 3.86908
# [68]	valid_0's multi_logloss: 3.86823
# [69]	valid_0's multi_logloss: 3.86753
# [70]	valid_0's multi_logloss: 3.86674
# [71]	valid_0's multi_logloss: 3.8659
# [72]	valid_0's multi_logloss: 3.86525
# [73]	valid_0's multi_logloss: 3.86471
# [74]	valid_0's multi_logloss: 3.86398
# [75]	valid_0's multi_logloss: 3.86341
# [76]	valid_0's multi_logloss: 3.86278
# [77]	valid_0's multi_logloss: 3.86223
# [78]	valid_0's multi_logloss: 3.86166
# [79]	valid_0's multi_logloss: 3.86119
# [80]	valid_0's multi_logloss: 3.86082
# [81]	valid_0's multi_logloss: 3.86037
# [82]	valid_0's multi_logloss: 3.85982
# [83]	valid_0's multi_logloss: 3.85945
# [84]	valid_0's multi_logloss: 3.85907
# [85]	valid_0's multi_logloss: 3.85868
# [86]	valid_0's multi_logloss: 3.85845
# [87]	valid_0's multi_logloss: 3.85809
# [88]	valid_0's multi_logloss: 3.85771
# [89]	valid_0's multi_logloss: 3.85735
# [90]	valid_0's multi_logloss: 3.8571
# [91]	valid_0's multi_logloss: 3.85677
# [92]	valid_0's multi_logloss: 3.8566
# [93]	valid_0's multi_logloss: 3.85639
# [94]	valid_0's multi_logloss: 3.85617
# [95]	valid_0's multi_logloss: 3.85591
# [96]	valid_0's multi_logloss: 3.85567
# [97]	valid_0's multi_logloss: 3.85547
# [98]	valid_0's multi_logloss: 3.8553
# [99]	valid_0's multi_logloss: 3.85502
# [100]	valid_0's multi_logloss: 3.8548

# %%
y_pred = model.predict(X_test, num_iteration=model.best_iteration)
y_pred_max = np.argmax(y_pred, axis=1)  # 最尤と判断したクラスの値にする

# 精度 (Accuracy) を計算する
accuracy = sum(y_test['funaken'] == y_pred_max) / len(y_test)
print("accuracy:",accuracy)

# 回収率を計算
res=0
for i in range(len(y_test)):
    if (y_test.iloc[i])['funaken']==y_pred_max[i]:
        #print("i:",i,"result:",y_test[i],"forecast:",y_pred_max[i],"forecastProb:",y_pred[i][y_pred_max[i]],"return:",o_test[i],"expect:",y_pred[i][y_pred_max[i]]*o_test[i])
        res += o_test[i] -1
    else:
        #print("i:",i,"result:",y_test[i],"forecast:",y_pred_max[i],"forecastProb:",y_pred[i][y_pred_max[i]],"return:",o_test[i],"expect:",y_pred[i][y_pred_max[i]]*o_test[i])
        pass
print("resultReturn:",res/len(y_test))
# Out:
# accuracy: 0.09200309130386781
# resultReturn: 0.7315681006881847

# %%
print(len(y_pred))
# オッズを見て判断する場合
resAmount=0
buyAmount=0

dfIndexList=y_test['funaken'].index
for i in range(len(y_test)):
    raceId = df.iloc[dfIndexList[i]]['raceId']
    #print(raceId)
    with dbh.cursor() as cursor:
        sel_sql = "select funaken,odds from raceodds \
                   where oddsType = '3t' \
                   and raceId = '%s' \
                   order by funaken" \
                   % (raceId)
        cursor.execute(sel_sql)
        loadList=pd.DataFrame(cursor.fetchall())
        loadList=pd.DataFrame(loadList.replace(funakenDict))
    #print((loadList[loadList['funaken']==0]['odds'] * y_pred[i][0] ).values[0] )
    #if ( (loadList[loadList['funaken']==0]['odds'] * y_pred[i][0] ).values[0] > 1) :
    #    print("ok")
    #print(y_pred[i][0])
    #print(raceId)
    for j in range(120):
        if y_pred[i][j]> 0.10 and ( (y_pred[i][j] * (loadList[loadList['funaken']==j]['odds'])).values[0] > 1.5) :
            print("buy:",raceId,i,j,loadList[loadList['funaken']==j]['odds'].values[0])
            buyAmount+=1
            if y_test['funaken'].iloc[i]==j:
            #print("i:",i,"result:",y_test[i],"forecast:",y_pred_max[i],"forecastProb:",y_pred[i][y_pred_max[i]],"return:",o_test[i],"expect:",y_pred[i][y_pred_max[i]]*o_test[i])
                print("☆hit!☆:",raceId,j,loadList[loadList['funaken']==j]['odds'].values[0])
                resAmount += o_test[i]
            else:
            #print("i:",i,"result:",y_test[i],"forecast:",y_pred_max[i],"forecastProb:",y_pred[i][y_pred_max[i]],"return:",o_test[i],"expect:",y_pred[i][y_pred_max[i]]*o_test[i])
# ☆hit!☆: 20171012-09-04 0 9.3
# buy: 20180319-09-05 25830 0 12.9
# buy: 20190111-16-01 25837 0 16.5
# buy: 20170425-09-12 25924 0 20.8
# buy: 20180918-21-04 25973 2 24.3
# buy: 20170811-24-01 25998 2 16.9
# buy: 20180316-19-05 26074 11 15.3
# buy: 20180512-08-05 26153 0 16.8
# buy: 20170821-17-08 26196 0 18.0
# buy: 20170621-20-07 26274 0 13.3
# buy: 20170607-01-07 26313 0 20.5
# buy: 20181226-20-08 26325 0 22.6
# buy: 20180517-13-10 26403 18 11.0
# buy: 20171102-09-08 26423 1 14.3
# buy: 20180507-06-07 26537 23 20.4
# buy: 20190312-17-05 26545 1 16.0
# buy: 20171015-23-01 26681 7 17.8
# buy: 20180322-12-07 26723 0 13.7
# buy: 20171211-09-01 26770 4 15.2
# buy: 20171219-19-01 26785 0 12.1
# buy: 20180304-18-09 26855 0 10.5
# buy: 20180207-21-03 26929 0 12.8
# buy: 20180812-02-09 26932 0 19.7
# buy: 20180114-08-12 27022 5 13.8
# buy: 20170622-06-04 27140 0 16.1
# buy: 20170622-06-04 27140 4 14.1
# resultReturn: 1.3141430948419304

# %%
print("totalRace,buy,return",len(y_test),buyAmount,resAmount )
# Out:
# totalRace,buy,return 27173 601 789.8000000000002

# %%
# trainの回収率を計算
y_pred = model.predict(X_train, num_iteration=model.best_iteration)
y_pred_max = np.argmax(y_pred, axis=1)  # 最尤と判断したクラスの値にする

#print(X_train.head())
#print(y_train[0:5])
#print(y_pred_max[0:5])
#c = collections.Counter(y_pred_max)
#print(len(c) )

# 精度 (Accuracy) を計算する
accuracy = sum(y_train == y_pred_max) / len(y_train)
print("accuracy:",accuracy)

# 回収率を計算
res=0
for i in range(len(y_train)):
    if y_train.iloc[i]==y_pred_max[i]:
        res += o_train[i] -1
    else:
        pass
print("return:",res/len(y_train))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-34acaf71e785> in <module>
#      10
#      11 # 精度 (Accuracy) を計算する
# ---> 12 accuracy = sum(y_train == y_pred_max) / len(y_train)
#      13 print("accuracy:",accuracy)
#      14
#
# ~/.pyenv/versions/anaconda3-2018.12/lib/python3.6/site-packages/pandas/core/ops.py in f(self, other)
#    2089     def f(self, other):
#    2090
# -> 2091         other = _align_method_FRAME(self, other, axis=None)
#    2092
#    2093         if isinstance(other, ABCDataFrame):
#
# ~/.pyenv/versions/anaconda3-2018.12/lib/python3.6/site-packages/pandas/core/ops.py in _align_method_FRAME(left, right, axis)
#    1952
#    1953         if right.ndim == 1:
# -> 1954             right = to_series(right)
#    1955
#    1956         elif right.ndim == 2:
#
# ~/.pyenv/versions/anaconda3-2018.12/lib/python3.6/site-packages/pandas/core/ops.py in to_series(right)
#    1945             if len(left.columns) != len(right):
#    1946                 raise ValueError(msg.format(req_len=len(left.columns),
# -> 1947                                             given_len=len(right)))
#    1948             right = left._constructor_sliced(right, index=left.columns)
#    1949         return right
#
# ValueError: Unable to coerce to Series, length must be 1: given 81516

# %%
print(y_pred[0])

# %%
print(df.iloc[X_train.index]['raceId'])

# %%
print(model.feature_importance())
