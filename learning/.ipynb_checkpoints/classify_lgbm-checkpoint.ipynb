# %%
# 選手情報・過去レース情報から3連単舟券120種をクラス分類する
# LGBMでやってみる。
# todo:bayseの方と、インプットの与え方をあわせる。今はOne-Hotが一致していない。
# 的中予想確率10%以上のうち、オッズで見合うものだけ買った場合のシミュレーションをする。

# 汎用ライブラリのimport
import sys
import os
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import statsmodels.api as sm
import math
import tensorflow as tf
import collections

import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import csv

# %%
# 自作ライブラリのimport
if os.environ['BR_HOME']+"/boatrace" not in sys.path:
    sys.path.append(os.environ['BR_HOME']+"/boatrace")
#print(sys.path)

from setup.myUtil import dbHandler

# %%
# 舟券の配列を取得
funakenList=[]
with open(os.environ['BR_HOME']+'/boatrace/config/3t_list.dat') as f:
    reader=csv.reader(f)
    for row in reader:
        funakenList.append(row)
funakenID = [i for i in range(120)]
funakenDict=dict(zip(funakenList[0],funakenID))
print(funakenDict)
# Out:
# {'1-2-3': 0, '1-2-4': 1, '1-2-5': 2, '1-2-6': 3, '1-3-2': 4, '1-3-4': 5, '1-3-5': 6, '1-3-6': 7, '1-4-2': 8, '1-4-3': 9, '1-4-5': 10, '1-4-6': 11, '1-5-2': 12, '1-5-3': 13, '1-5-4': 14, '1-5-6': 15, '1-6-2': 16, '1-6-3': 17, '1-6-4': 18, '1-6-5': 19, '2-1-3': 20, '2-1-4': 21, '2-1-5': 22, '2-1-6': 23, '2-3-1': 24, '2-3-4': 25, '2-3-5': 26, '2-3-6': 27, '2-4-1': 28, '2-4-3': 29, '2-4-5': 30, '2-4-6': 31, '2-5-1': 32, '2-5-3': 33, '2-5-4': 34, '2-5-6': 35, '2-6-1': 36, '2-6-3': 37, '2-6-4': 38, '2-6-5': 39, '3-1-2': 40, '3-1-4': 41, '3-1-5': 42, '3-1-6': 43, '3-2-1': 44, '3-2-4': 45, '3-2-5': 46, '3-2-6': 47, '3-4-1': 48, '3-4-2': 49, '3-4-5': 50, '3-4-6': 51, '3-5-1': 52, '3-5-2': 53, '3-5-4': 54, '3-5-6': 55, '3-6-1': 56, '3-6-2': 57, '3-6-4': 58, '3-6-5': 59, '4-1-2': 60, '4-1-3': 61, '4-1-5': 62, '4-1-6': 63, '4-2-1': 64, '4-2-3': 65, '4-2-5': 66, '4-2-6': 67, '4-3-1': 68, '4-3-2': 69, '4-3-5': 70, '4-3-6': 71, '4-5-1': 72, '4-5-2': 73, '4-5-3': 74, '4-5-6': 75, '4-6-1': 76, '4-6-2': 77, '4-6-3': 78, '4-6-5': 79, '5-1-2': 80, '5-1-3': 81, '5-1-4': 82, '5-1-6': 83, '5-2-1': 84, '5-2-3': 85, '5-2-4': 86, '5-2-6': 87, '5-3-1': 88, '5-3-2': 89, '5-3-4': 90, '5-3-6': 91, '5-4-1': 92, '5-4-2': 93, '5-4-3': 94, '5-4-6': 95, '5-6-1': 96, '5-6-2': 97, '5-6-3': 98, '5-6-4': 99, '6-1-2': 100, '6-1-3': 101, '6-1-4': 102, '6-1-5': 103, '6-2-1': 104, '6-2-3': 105, '6-2-4': 106, '6-2-5': 107, '6-3-1': 108, '6-3-2': 109, '6-3-4': 110, '6-3-5': 111, '6-4-1': 112, '6-4-2': 113, '6-4-3': 114, '6-4-5': 115, '6-5-1': 116, '6-5-2': 117, '6-5-3': 118, '6-5-4': 119}

# %%
# 分析期間の指定は一旦ここでまとめてみる。
trainStartDate="20170401"
trainEndDate="20190331"
# test はtrainからsplitする

# %%
dbh=dbHandler.getDBHandle()
#dbHandler.closeDBHandle(dbh)

# %%
# trainの元データを取得
with dbh.cursor() as cursor:
    sel_sql = "select * from raceabst_forml_v \
               where raceDate between '%s' and '%s' \
               order by raceId "\
               % (trainStartDate,trainEndDate)
    cursor.execute(sel_sql)
    loadList=cursor.fetchall()
print("traindata:",len(loadList))

# %%
df = pd.io.json.json_normalize(loadList)
df.head()

# %%
# 入力のデータ整形
#xdf=df.drop(['funaken','odds','raceId','raceDate'],axis=1)
#xdf=pd.get_dummies(xdf,columns=['l1rank','l2rank','l3rank','l4rank','l5rank','l6rank'])
#xdf.head()

# 入力のデータ整形
xdf=df.drop(['funaken','odds','raceId','raceDate'],axis=1)
#xdf=pd.get_dummies(xdf,columns=['l1rank','l2rank','l3rank','l4rank','l5rank','l6rank'])
rankLabel=LabelEncoder()
rankLabel=rankLabel.fit(xdf['l1rank'])
xdf['l1rank']=rankLabel.transform(xdf['l1rank'])
xdf['l2rank']=rankLabel.transform(xdf['l2rank'])
xdf['l3rank']=rankLabel.transform(xdf['l3rank'])
xdf['l4rank']=rankLabel.transform(xdf['l4rank'])
xdf['l5rank']=rankLabel.transform(xdf['l5rank'])
xdf['l6rank']=rankLabel.transform(xdf['l6rank'])
xdf.head()

# %%
# ファイルから作った辞書で変換する
ydf=df['funaken']
ydf=pd.DataFrame(ydf.replace(funakenDict))
print(ydf.head())
# Out:
#    funaken
# 0       12
# 1       20
# 2       24
# 3        8
# 4        1

# %%
# 重み付けのため、オッズのリストを作る
odf=df['odds'].values
#odf=pd.DataFrame(df['odds'])
#odf.describe()
print(odf)
# Out:
# [  30.3   79.    28.9 ...   13.6 1094.    29.2]

# %%
X_train, X_test, y_train, y_test,o_train,o_test = train_test_split(xdf, ydf,odf)

# %%
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# %%
lgbm_params = {
    # 多値分類問題
    'objective': 'multiclass',
    # クラス数は 120
    'num_class': 120,
    #'class_weight':'balanced',
    #'random_state':999,
    # 以下、ハイパーパラメタ
    'max_depth':3,
    'num_leaves':6,
    'min_data_in_leaf':300,
    # 正則化
    'reg_alpha':2.425,
    'reg_lambda':9.473 ,
}

# %%
lgb.LGBMClassifier()
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
model = lgb.train(lgbm_params, lgb_train, valid_sets=lgb_eval)
# Out:
# [1]	valid_0's multi_logloss: 4.66151
# [2]	valid_0's multi_logloss: 4.57109
# [3]	valid_0's multi_logloss: 4.49997
# [4]	valid_0's multi_logloss: 4.44077
# [5]	valid_0's multi_logloss: 4.39019
# [6]	valid_0's multi_logloss: 4.34642
# [7]	valid_0's multi_logloss: 4.30798
# [8]	valid_0's multi_logloss: 4.27393
# [9]	valid_0's multi_logloss: 4.24323
# [10]	valid_0's multi_logloss: 4.2157
# [11]	valid_0's multi_logloss: 4.19099
# [12]	valid_0's multi_logloss: 4.16826
# [13]	valid_0's multi_logloss: 4.14784
# [14]	valid_0's multi_logloss: 4.12905
# [15]	valid_0's multi_logloss: 4.11165
# [16]	valid_0's multi_logloss: 4.0958
# [17]	valid_0's multi_logloss: 4.08103
# [18]	valid_0's multi_logloss: 4.06756
# [19]	valid_0's multi_logloss: 4.05495
# [20]	valid_0's multi_logloss: 4.04312
# [21]	valid_0's multi_logloss: 4.03223
# [22]	valid_0's multi_logloss: 4.02213
# [23]	valid_0's multi_logloss: 4.01263
# [24]	valid_0's multi_logloss: 4.00378
# [25]	valid_0's multi_logloss: 3.99546
# [26]	valid_0's multi_logloss: 3.98782
# [27]	valid_0's multi_logloss: 3.98048
# [28]	valid_0's multi_logloss: 3.97357
# [29]	valid_0's multi_logloss: 3.96718
# [30]	valid_0's multi_logloss: 3.96104
# [31]	valid_0's multi_logloss: 3.95541
# [32]	valid_0's multi_logloss: 3.95016
# [33]	valid_0's multi_logloss: 3.94519
# [34]	valid_0's multi_logloss: 3.94053
# [35]	valid_0's multi_logloss: 3.93595
# [36]	valid_0's multi_logloss: 3.93167
# [37]	valid_0's multi_logloss: 3.92783
# [38]	valid_0's multi_logloss: 3.92414
# [39]	valid_0's multi_logloss: 3.92061
# [40]	valid_0's multi_logloss: 3.91719
# [41]	valid_0's multi_logloss: 3.91399
# [42]	valid_0's multi_logloss: 3.91093
# [43]	valid_0's multi_logloss: 3.90806
# [44]	valid_0's multi_logloss: 3.9054
# [45]	valid_0's multi_logloss: 3.90268
# [46]	valid_0's multi_logloss: 3.90013
# [47]	valid_0's multi_logloss: 3.89794
# [48]	valid_0's multi_logloss: 3.89564
# [49]	valid_0's multi_logloss: 3.89359
# [50]	valid_0's multi_logloss: 3.89172
# [51]	valid_0's multi_logloss: 3.88969
# [52]	valid_0's multi_logloss: 3.88772
# [53]	valid_0's multi_logloss: 3.88608
# [54]	valid_0's multi_logloss: 3.88456
# [55]	valid_0's multi_logloss: 3.883
# [56]	valid_0's multi_logloss: 3.88157
# [57]	valid_0's multi_logloss: 3.8801
# [58]	valid_0's multi_logloss: 3.87874
# [59]	valid_0's multi_logloss: 3.87744
# [60]	valid_0's multi_logloss: 3.87629
# [61]	valid_0's multi_logloss: 3.87503
# [62]	valid_0's multi_logloss: 3.87384
# [63]	valid_0's multi_logloss: 3.87288
# [64]	valid_0's multi_logloss: 3.87196
# [65]	valid_0's multi_logloss: 3.87096
# [66]	valid_0's multi_logloss: 3.87002
# [67]	valid_0's multi_logloss: 3.86914
# [68]	valid_0's multi_logloss: 3.86814
# [69]	valid_0's multi_logloss: 3.86738
# [70]	valid_0's multi_logloss: 3.86657
# [71]	valid_0's multi_logloss: 3.86578
# [72]	valid_0's multi_logloss: 3.86499
# [73]	valid_0's multi_logloss: 3.86444
# [74]	valid_0's multi_logloss: 3.8638
# [75]	valid_0's multi_logloss: 3.86317
# [76]	valid_0's multi_logloss: 3.86257
# [77]	valid_0's multi_logloss: 3.862
# [78]	valid_0's multi_logloss: 3.86141
# [79]	valid_0's multi_logloss: 3.86086
# [80]	valid_0's multi_logloss: 3.86037
# [81]	valid_0's multi_logloss: 3.85988
# [82]	valid_0's multi_logloss: 3.85945
# [83]	valid_0's multi_logloss: 3.85896
# [84]	valid_0's multi_logloss: 3.85851
# [85]	valid_0's multi_logloss: 3.85808
# [86]	valid_0's multi_logloss: 3.85774
# [87]	valid_0's multi_logloss: 3.85737
# [88]	valid_0's multi_logloss: 3.85697
# [89]	valid_0's multi_logloss: 3.85665
# [90]	valid_0's multi_logloss: 3.85632
# [91]	valid_0's multi_logloss: 3.85599
# [92]	valid_0's multi_logloss: 3.85573
# [93]	valid_0's multi_logloss: 3.85535
# [94]	valid_0's multi_logloss: 3.85505
# [95]	valid_0's multi_logloss: 3.85473
# [96]	valid_0's multi_logloss: 3.85446
# [97]	valid_0's multi_logloss: 3.85424
# [98]	valid_0's multi_logloss: 3.85398
# [99]	valid_0's multi_logloss: 3.85378
# [100]	valid_0's multi_logloss: 3.85358

# %%
y_pred = model.predict(X_test, num_iteration=model.best_iteration)
y_pred_max = np.argmax(y_pred, axis=1)  # 最尤と判断したクラスの値にする

# 精度 (Accuracy) を計算する
accuracy = sum(y_test['funaken'] == y_pred_max) / len(y_test)
print("accuracy:",accuracy)

# 回収率を計算
res=0
for i in range(len(y_test)):
    if (y_test.iloc[i])['funaken']==y_pred_max[i]:
        #print("i:",i,"result:",y_test[i],"forecast:",y_pred_max[i],"forecastProb:",y_pred[i][y_pred_max[i]],"return:",o_test[i],"expect:",y_pred[i][y_pred_max[i]]*o_test[i])
        res += o_test[i] -1
    else:
        #print("i:",i,"result:",y_test[i],"forecast:",y_pred_max[i],"forecastProb:",y_pred[i][y_pred_max[i]],"return:",o_test[i],"expect:",y_pred[i][y_pred_max[i]]*o_test[i])
        pass
print("resultReturn:",res/len(y_test))
# Out:
# accuracy: 0.08861737754388548
# resultReturn: 0.7107312405696822

# %%
print(len(y_pred))
# オッズを見て判断する場合
resAmount=0
buyAmount=0

dfIndexList=y_test['funaken'].index
for i in range(len(y_test)):
    raceId = df.iloc[dfIndexList[i]]['raceId']
    #print(raceId)
    with dbh.cursor() as cursor:
        sel_sql = "select funaken,odds from raceodds \
                   where oddsType = '3t' \
                   and raceId = '%s' \
                   order by funaken" \
                   % (raceId)
        cursor.execute(sel_sql)
        loadList=pd.DataFrame(cursor.fetchall())
        loadList=pd.DataFrame(loadList.replace(funakenDict))
    #print((loadList[loadList['funaken']==0]['odds'] * y_pred[i][0] ).values[0] )
    #if ( (loadList[loadList['funaken']==0]['odds'] * y_pred[i][0] ).values[0] > 1) :
    #    print("ok")
    #print(y_pred[i][0])
    #print(raceId)
    for j in range(120):
        if y_pred[i][j]> 0.10 and ( (y_pred[i][j] * (loadList[loadList['funaken']==j]['odds'])).values[0] > 1.5) :
            print("buy:",raceId,i,j,loadList[loadList['funaken']==j]['odds'].values[0])
            buyAmount+=1
            if y_test['funaken'].iloc[i]==j:
            #print("i:",i,"result:",y_test[i],"forecast:",y_pred_max[i],"forecastProb:",y_pred[i][y_pred_max[i]],"return:",o_test[i],"expect:",y_pred[i][y_pred_max[i]]*o_test[i])
                print("☆hit!☆:",raceId,j,loadList[loadList['funaken']==j]['odds'].values[0])
                resAmount += o_test[i]
            else:
            #print("i:",i,"result:",y_test[i],"forecast:",y_pred_max[i],"forecastProb:",y_pred[i][y_pred_max[i]],"return:",o_test[i],"expect:",y_pred[i][y_pred_max[i]]*o_test[i])
                pass
print("resultReturn:",resAmount/buyAmount)
# Out:
# 27173
# buy: 20180406-09-04 9 1 16.6
# buy: 20170702-08-11 73 0 17.0
# buy: 20190123-16-01 79 0 13.1
# buy: 20190123-16-01 79 4 17.3
# buy: 20190127-14-01 92 0 12.1
# buy: 20171203-06-08 107 2 9.9
# buy: 20170404-09-12 116 0 13.8
# buy: 20170805-08-07 134 0 14.8
# buy: 20180621-22-11 145 0 12.1
# ☆hit!☆: 20180621-22-11 0 12.1
# buy: 20180329-23-02 176 0 8.7
# buy: 20171109-21-04 215 0 13.4
# buy: 20170922-05-09 259 0 14.1
# buy: 20170922-05-09 259 4 15.8
# buy: 20170702-20-05 299 0 13.3
# buy: 20180208-24-04 339 41 17.2
# ☆hit!☆: 20180208-24-04 41 17.2
# buy: 20170628-15-08 340 0 15.0
# buy: 20190325-16-06 349 1 13.5
# buy: 20171128-24-05 507 1 12.5
# buy: 20170925-22-01 519 8 13.6
# buy: 20180128-21-04 615 0 12.9
# buy: 20181126-10-05 778 5 11.2
# buy: 20171211-01-06 859 0 27.3
# buy: 20180126-20-08 882 0 12.2
# buy: 20181205-01-06 892 0 13.2
# buy: 20180107-13-07 934 6 22.3
# buy: 20170421-01-06 938 0 12.0
# buy: 20181223-09-07 994 0 18.8
# buy: 20180614-09-12 998 11 14.8
# buy: 20171122-23-01 1040 0 11.2
# ☆hit!☆: 20171122-23-01 0 11.2
# buy: 20180824-24-03 1097 10 17.8
# buy: 20170427-16-04 1115 0 14.0
# buy: 20190106-16-07 1220 8 15.3
# buy: 20190205-23-03 1538 0 14.0
# buy: 20180920-21-05 1539 2 12.3
# buy: 20170930-20-05 1564 0 16.0
# buy: 20181118-08-06 1614 4 17.2
# buy: 20181118-08-06 1614 7 11.7
# ☆hit!☆: 20181118-08-06 7 11.7
# buy: 20180702-21-04 1617 1 16.1
# ☆hit!☆: 20180702-21-04 1 16.1
# buy: 20170730-19-01 1629 0 11.4
# buy: 20180103-03-02 1636 0 18.9
# buy: 20181009-21-07 1672 0 12.0
# ☆hit!☆: 20181009-21-07 0 12.0
# buy: 20181124-09-09 1738 1 18.9
# buy: 20180608-10-02 26437 2 15.1
# buy: 20170418-18-03 26505 0 16.7
# buy: 20180505-12-04 26528 1 14.5
# ☆hit!☆: 20180505-12-04 1 14.5
# buy: 20181229-19-10 26548 0 12.2
# buy: 20170505-01-07 26591 0 15.3
# buy: 20180117-11-07 26611 0 10.6
# ☆hit!☆: 20180117-11-07 0 10.6
# buy: 20180916-02-12 26612 0 12.8
# buy: 20181209-09-04 26615 2 16.6
# buy: 20171025-05-06 26693 0 14.9
# buy: 20180401-19-01 26857 0 11.6
# buy: 20181228-19-08 26966 4 16.0
# buy: 20170701-10-11 26987 0 11.9
# buy: 20181014-17-10 27020 0 16.3
# buy: 20170702-05-10 27066 0 18.5
# resultReturn: 0.8666144200626958

# %%
print("totalRace,buy,return",len(y_test),buyAmount,resAmount )
# Out:
# totalRace,buy,return 27173 638 552.9

# %%
# trainの回収率を計算
y_pred = model.predict(X_train, num_iteration=model.best_iteration)
y_pred_max = np.argmax(y_pred, axis=1)  # 最尤と判断したクラスの値にする

#print(X_train.head())
#print(y_train[0:5])
#print(y_pred_max[0:5])
#c = collections.Counter(y_pred_max)
#print(len(c) )

# 精度 (Accuracy) を計算する
#accuracy = sum(y_train == y_pred_max) / len(y_train)
#print("accuracy:",accuracy)

# 回収率を計算
res=0
for i in range(len(y_train)):
    if y_train.iloc[i]==y_pred_max[i]:
        res += o_train[i] -1
    else:
        pass
print("return:",res/len(y_train))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-ce34cb397c3b> in <module>
#      16 res=0
#      17 for i in range(len(y_train)):
# ---> 18     if y_train.iloc[i]==y_pred_max[i]:
#      19         res += o_train[i] -1
#      20     else:
#
# ~/.pyenv/versions/anaconda3-2018.12/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
print(y_pred[0])

# %%
print(df.iloc[X_train.index]['raceId'])

# %%
print(xdf.columns)
# Out:
# Index(['l1Fcnt', 'l1boat2r', 'l1boat3r', 'l1motor2r', 'l1motor3r', 'l1rank',
#        'l1score', 'l2Fcnt', 'l2boat2r', 'l2boat3r', 'l2motor2r', 'l2motor3r',
#        'l2rank', 'l2score', 'l3Fcnt', 'l3boat2r', 'l3boat3r', 'l3motor2r',
#        'l3motor3r', 'l3rank', 'l3score', 'l4Fcnt', 'l4boat2r', 'l4boat3r',
#        'l4motor2r', 'l4motor3r', 'l4rank', 'l4score', 'l5Fcnt', 'l5boat2r',
#        'l5boat3r', 'l5motor2r', 'l5motor3r', 'l5rank', 'l5score', 'l6Fcnt',
#        'l6boat2r', 'l6boat3r', 'l6motor2r', 'l6motor3r', 'l6rank', 'l6score',
#        'raceWaveHeight', 'raceWindSpeed'],
#       dtype='object')

# %%
print(model.feature_importance())
# Out:
# [  37  697  800  630  799  168 5425   24  700  773  641  730  383 5956
#    43  685  679  733  744  571 5992   42  681  654  708  707  551 6784
#    35  690  721  707  723  757 7557   63  606  722  742  733  713 7186
#   290  307]
